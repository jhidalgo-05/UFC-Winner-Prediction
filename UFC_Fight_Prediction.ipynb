# %% [markdown]
# # DATA CLEANING AND FEATURE ENGINEERING

# %%
# main libraries used
import pandas as pd
import numpy as np
import os

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("maksbasher/ufc-complete-dataset-all-events-1996-2024")

print("Path to dataset files:", path)

# look at all data files
print(os.listdir(path))

# look at inner files from the folder
inner_path = os.path.join(path, "UFC dataset")
print(os.listdir(inner_path))
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.13), please consider upgrading to the latest version (1.0.2).
# Path to dataset files: C:\Users\joaqu\.cache\kagglehub\datasets\maksbasher\ufc-complete-dataset-all-events-1996-2024\versions\6
# ['UFC dataset']
# ['Fighter stats', 'Large set', 'Medium set', 'Small set', 'Urls']

# %%
# Paths to the datasets that will be used for the project

base_path = path
large_set_path = os.path.join(base_path, "UFC dataset", "Large set")
fighter_stats_path = os.path.join(base_path, "UFC dataset", "Fighter stats")
medium_set_with_event_date = os.path.join(base_path, "UFC dataset", "Medium set")

# %%
# extract csv files from the API

def load_csvs_from_folder(folder_path):
    csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]
    dataframes = {}

    for file in csv_files:
        full_path = os.path.join(folder_path, file)
        df = pd.read_csv(full_path, encoding="utf-8", low_memory=False)
        dataframes[file] = df
        print(f"Loaded: {file} — shape {df.shape}")

    return df

df = load_csvs_from_folder(large_set_path)
# Out:
# Loaded: large_dataset.csv — shape (7439, 95)

# %%
# load second dataset with dates
path = r"C:\Users\joaqu\Downloads\large_dataset_with_event_date_from_ufcstats.csv" # local file found in github
assert os.path.exists(path)

df2 = pd.read_csv(path)

# %%
# first look into the data
print(df.info())
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7439 entries, 0 to 7438
# Data columns (total 95 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   event_name              7439 non-null   object
#  1   r_fighter               7439 non-null   object
#  2   b_fighter               7439 non-null   object
#  3   winner                  7439 non-null   object
#  4   weight_class            7439 non-null   object
#  5   is_title_bout           7439 non-null   int64
#  6   gender                  7439 non-null   object
#  7   method                  7439 non-null   object
#  8   finish_round            7439 non-null   int64
#  9   total_rounds            7408 non-null   float64
#  10  time_sec                7439 non-null   int64
#  11  referee                 7407 non-null   object
#  12  r_kd                    7439 non-null   int64
#  13  r_sig_str               7439 non-null   int64
#  14  r_sig_str_att           7439 non-null   int64
#  15  r_sig_str_acc           7439 non-null   float64
#  16  r_str                   7439 non-null   int64
#  17  r_str_att               7439 non-null   int64
#  18  r_str_acc               7439 non-null   float64
#  19  r_td                    7439 non-null   int64
#  20  r_td_att                7439 non-null   int64
#  21  r_td_acc                7439 non-null   float64
#  22  r_sub_att               7439 non-null   int64
#  23  r_rev                   7439 non-null   int64
#  24  r_ctrl_sec              7439 non-null   int64
#  25  r_wins_total            7439 non-null   int64
#  26  r_losses_total          7439 non-null   int64
#  27  r_age                   7363 non-null   float64
#  28  r_height                7439 non-null   float64
#  29  r_weight                7439 non-null   float64
#  30  r_reach                 7027 non-null   float64
#  31  r_stance                7413 non-null   object
#  32  r_SLpM_total            7439 non-null   float64
#  33  r_SApM_total            7439 non-null   float64
#  34  r_sig_str_acc_total     7439 non-null   float64
#  35  r_td_acc_total          7439 non-null   float64
#  36  r_str_def_total         7439 non-null   float64
#  37  r_td_def_total          7439 non-null   float64
#  38  r_sub_avg               7439 non-null   float64
#  39  r_td_avg                7439 non-null   float64
#  40  b_kd                    7439 non-null   int64
#  41  b_sig_str               7439 non-null   int64
#  42  b_sig_str_att           7439 non-null   int64
#  43  b_sig_str_acc           7439 non-null   float64
#  44  b_str                   7439 non-null   int64
#  45  b_str_att               7439 non-null   int64
#  46  b_str_acc               7439 non-null   float64
#  47  b_td                    7439 non-null   int64
#  48  b_td_att                7439 non-null   int64
#  49  b_td_acc                7439 non-null   float64
#  50  b_sub_att               7439 non-null   int64
#  51  b_rev                   7439 non-null   int64
#  52  b_ctrl_sec              7439 non-null   int64
#  53  b_wins_total            7439 non-null   int64
#  54  b_losses_total          7439 non-null   int64
#  55  b_age                   7249 non-null   float64
#  56  b_height                7439 non-null   float64
#  57  b_weight                7439 non-null   float64
#  58  b_reach                 6551 non-null   float64
#  59  b_stance                7371 non-null   object
#  60  b_SLpM_total            7439 non-null   float64
#  61  b_SApM_total            7439 non-null   float64
#  62  b_sig_str_acc_total     7439 non-null   float64
#  63  b_td_acc_total          7439 non-null   float64
#  64  b_str_def_total         7439 non-null   float64
#  65  b_td_def_total          7439 non-null   float64
#  66  b_sub_avg               7439 non-null   float64
#  67  b_td_avg                7439 non-null   float64
#  68  kd_diff                 7439 non-null   int64
#  69  sig_str_diff            7439 non-null   int64
#  70  sig_str_att_diff        7439 non-null   int64
#  71  sig_str_acc_diff        7439 non-null   float64
#  72  str_diff                7439 non-null   int64
#  73  str_att_diff            7439 non-null   int64
#  74  str_acc_diff            7439 non-null   float64
#  75  td_diff                 7439 non-null   int64
#  76  td_att_diff             7439 non-null   int64
#  77  td_acc_diff             7439 non-null   float64
#  78  sub_att_diff            7439 non-null   int64
#  79  rev_diff                7439 non-null   int64
#  80  ctrl_sec_diff           7439 non-null   int64
#  81  wins_total_diff         7439 non-null   int64
#  82  losses_total_diff       7439 non-null   int64
#  83  age_diff                7226 non-null   float64
#  84  height_diff             7439 non-null   float64
#  85  weight_diff             7439 non-null   float64
#  86  reach_diff              6401 non-null   float64
#  87  SLpM_total_diff         7439 non-null   float64
#  88  SApM_total_diff         7439 non-null   float64
#  89  sig_str_acc_total_diff  7439 non-null   float64
#  90  td_acc_total_diff       7439 non-null   float64
#  91  str_def_total_diff      7439 non-null   float64
#  92  td_def_total_diff       7439 non-null   float64
#  93  sub_avg_diff            7439 non-null   float64
#  94  td_avg_diff             7439 non-null   float64
# dtypes: float64(46), int64(39), object(10)
# memory usage: 5.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7439 entries, 0 to 7438
# Data columns (total 96 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   event_name              7439 non-null   object
#  1   event_date              7439 non-null   object
#  2   r_fighter               7439 non-null   object
#  3   b_fighter               7439 non-null   object
#  4   winner                  7439 non-null   object
#  5   weight_class            7439 non-null   object
#  6   is_title_bout           7439 non-null   int64
#  7   gender                  7439 non-null   object
#  8   method                  7439 non-null   object
#  9   finish_round            7439 non-null   int64
#  10  total_rounds            7408 non-null   float64
#  11  time_sec                7439 non-null   int64
#  12  referee                 7407 non-null   object
#  13  r_kd                    7439 non-null   int64
#  14  r_sig_str               7439 non-null   int64
#  15  r_sig_str_att           7439 non-null   int64
#  16  r_sig_str_acc           7439 non-null   float64
#  17  r_str                   7439 non-null   int64
#  18  r_str_att               7439 non-null   int64
#  19  r_str_acc               7439 non-null   float64
#  20  r_td                    7439 non-null   int64
#  21  r_td_att                7439 non-null   int64
#  22  r_td_acc                7439 non-null   float64
#  23  r_sub_att               7439 non-null   int64
#  24  r_rev                   7439 non-null   int64
#  25  r_ctrl_sec              7439 non-null   int64
#  26  r_wins_total            7439 non-null   int64
#  27  r_losses_total          7439 non-null   int64
#  28  r_age                   7363 non-null   float64
#  29  r_height                7439 non-null   float64
#  30  r_weight                7439 non-null   float64
#  31  r_reach                 7027 non-null   float64
#  32  r_stance                7413 non-null   object
#  33  r_SLpM_total            7439 non-null   float64
#  34  r_SApM_total            7439 non-null   float64
#  35  r_sig_str_acc_total     7439 non-null   float64
#  36  r_td_acc_total          7439 non-null   float64
#  37  r_str_def_total         7439 non-null   float64
#  38  r_td_def_total          7439 non-null   float64
#  39  r_sub_avg               7439 non-null   float64
#  40  r_td_avg                7439 non-null   float64
#  41  b_kd                    7439 non-null   int64
#  42  b_sig_str               7439 non-null   int64
#  43  b_sig_str_att           7439 non-null   int64
#  44  b_sig_str_acc           7439 non-null   float64
#  45  b_str                   7439 non-null   int64
#  46  b_str_att               7439 non-null   int64
#  47  b_str_acc               7439 non-null   float64
#  48  b_td                    7439 non-null   int64
#  49  b_td_att                7439 non-null   int64
#  50  b_td_acc                7439 non-null   float64
#  51  b_sub_att               7439 non-null   int64
#  52  b_rev                   7439 non-null   int64
#  53  b_ctrl_sec              7439 non-null   int64
#  54  b_wins_total            7439 non-null   int64
#  55  b_losses_total          7439 non-null   int64
#  56  b_age                   7249 non-null   float64
#  57  b_height                7439 non-null   float64
#  58  b_weight                7439 non-null   float64
#  59  b_reach                 6551 non-null   float64
#  60  b_stance                7371 non-null   object
#  61  b_SLpM_total            7439 non-null   float64
#  62  b_SApM_total            7439 non-null   float64
#  63  b_sig_str_acc_total     7439 non-null   float64
#  64  b_td_acc_total          7439 non-null   float64
#  65  b_str_def_total         7439 non-null   float64
#  66  b_td_def_total          7439 non-null   float64
#  67  b_sub_avg               7439 non-null   float64
#  68  b_td_avg                7439 non-null   float64
#  69  kd_diff                 7439 non-null   int64
#  70  sig_str_diff            7439 non-null   int64
#  71  sig_str_att_diff        7439 non-null   int64
#  72  sig_str_acc_diff        7439 non-null   float64
#  73  str_diff                7439 non-null   int64
#  74  str_att_diff            7439 non-null   int64
#  75  str_acc_diff            7439 non-null   float64
#  76  td_diff                 7439 non-null   int64
#  77  td_att_diff             7439 non-null   int64
#  78  td_acc_diff             7439 non-null   float64
#  79  sub_att_diff            7439 non-null   int64
#  80  rev_diff                7439 non-null   int64
#  81  ctrl_sec_diff           7439 non-null   int64
#  82  wins_total_diff         7439 non-null   int64
#  83  losses_total_diff       7439 non-null   int64
#  84  age_diff                7226 non-null   float64
#  85  height_diff             7439 non-null   float64
#  86  weight_diff             7439 non-null   float64
#  87  reach_diff              6401 non-null   float64
#  88  SLpM_total_diff         7439 non-null   float64
#  89  SApM_total_diff         7439 non-null   float64
#  90  sig_str_acc_total_diff  7439 non-null   float64
#  91  td_acc_total_diff       7439 non-null   float64
#  92  str_def_total_diff      7439 non-null   float64
#  93  td_def_total_diff       7439 non-null   float64
#  94  sub_avg_diff            7439 non-null   float64
#  95  td_avg_diff             7439 non-null   float64
# dtypes: float64(46), int64(39), object(11)
# memory usage: 5.4+ MB
# None

# %%
# load lookup table
date_lookup = df2[['event_name', 'r_fighter', 'b_fighter', 'event_date']]

# Ensure uniqueness (VERY IMPORTANT)
date_lookup = date_lookup.drop_duplicates(
    subset=['event_name', 'r_fighter', 'b_fighter']
)

# Remove old date columns
df = df.drop(columns=['event_date', 'event_date_x', 'event_date_y', 'date'], errors='ignore')

# Merge
df = df.merge(
    date_lookup,
    on=['event_name', 'r_fighter', 'b_fighter'],
    how='left'
)

# Validation checks
print("Missing event_date:", df['event_date'].isna().sum())
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Missing event_date: 0
# Duplicate rows: 0

# %%
# preserve fighter names before removing them
fighter_names = df[['r_fighter', 'b_fighter']]

# %% [markdown]
# ### Gender-Based Model Separation
#
# The dataset includes both men's and women's fights, which may exhibit different statistical patterns (e.g., striking rates, fight pace, and finishing tendencies).
#
# To account for these differences and improve model performance, we will split the dataset by gender and train separate models for each group. This allows each model to better capture the unique dynamics within men's and women's divisions, rather than forcing a single model to generalize across both.

# %%
# remove and store women fights for a separate study and accuracy purposes
wdf = df[df["gender"] == "Women"].copy()
mdf = df.drop(df[df["gender"] == "Women"].index).copy()

# %%
print(mdf.shape)
print(wdf.shape)
# Out:
# (6706, 96)
# (733, 96)

# %%
# confirming different statistical patterns between genders
target = ['reach_diff', 'age_diff', 'height_diff', 'weight_diff', 'total_rounds']

for targets in target:
    print(f'Mean for {targets}:\n')
    print(np.mean(mdf[targets]))
    print(np.mean(wdf[targets]))
    print('####################\n')
# Out:
# Mean for reach_diff:
#
# 0.2077736906638638
# 0.0440462427745665
# ####################
#
# Mean for age_diff:
#
# 0.39565686123517635
# 0.32060027285129605
# ####################
#
# Mean for height_diff:
#
# 0.021968386519534415
# 0.2668212824010909
# ####################
#
# Mean for weight_diff:
#
# 0.17752758723531162
# 0.11128240109140505
# ####################
#
# Mean for total_rounds:
#
# 3.1208988764044943
# 3.2019099590723057
# ####################

# %%
# look for missing values
missing = mdf.isnull().sum()
missing = missing[missing > 0]

print(missing)
# Out:
# total_rounds     31
# referee          27
# r_age            76
# r_reach         400
# r_stance         24
# b_age           190
# b_reach         859
# b_stance         63
# age_diff        213
# reach_diff      997
# dtype: int64

# %%
# mean imputation for all missing values (numeric)
vars = ["total_rounds", "r_age", "r_reach", "b_age", "b_reach", "age_diff", "reach_diff"]
for var in vars:   
    mdf[var] = mdf[var].fillna(mdf[var].mean())

# %%
# mode imputation for all missing values (categorical)
vars = ["r_stance", "b_stance"]
for var in vars:   
    mdf[var] = mdf[var].fillna(mdf[var].mode()[0])
    
# double check
missing = mdf.isnull().sum()
missing = missing[missing > 0]

print(missing)
# Out:
# referee    27
# dtype: int64

# %%
# check for duplicated fights
mdf.duplicated(subset=['r_fighter','b_fighter','event_date']).sum()
# Out:
# np.int64(0)

# %%
# check for class imbalance
mdf['winner'].value_counts(normalize=True)
# Out:
# winner
# Red     0.663883
# Blue    0.336117
# Name: proportion, dtype: float64

# %% [markdown]
# ### Addressing Class Imbalance
#
# To prevent the model from being biased toward the majority class, we address class imbalance in the dataset. This ensures that the model learns meaningful patterns from both outcomes rather than favoring the more frequent class, leading to more reliable and generalizable predictions.
#
# Invert r and b fighter statistics in a separate dataset. Concatenate and ensure 50/50 balance.

# %%
df_balanced = mdf.copy()
flipped = df_balanced.copy()

# swap fighters + winner
flipped[['r_fighter', 'b_fighter']] = flipped[['b_fighter', 'r_fighter']].values
flipped['winner'] = flipped['winner'].map({'Red': 'Blue', 'Blue': 'Red'})

# only flip columns that have BOTH r_ and b_ versions
r_cols = [c for c in df_balanced.columns if c.startswith('r_')]

for r_col in r_cols:
    b_col = r_col.replace('r_', 'b_')

    # ONLY flip if both exist
    if b_col in df_balanced.columns:
        flipped[r_col], flipped[b_col] = df_balanced[b_col], df_balanced[r_col]

# combine datasets
df_balanced = pd.concat([df_balanced, flipped], ignore_index=True)

# check balance
print(df_balanced['winner'].value_counts(normalize=True))
# Out:
# winner
# Red     0.5
# Blue    0.5
# Name: proportion, dtype: float64

# %% [markdown]
# Pre-Fight Feature Engineering for UFC Prediction Model
# -----------------------------
# This cell prepares the dataset for p
# predicting UFC fight outcomes using only information
#  available before the fight. It merges each fighter's historical career stats (e.g.,
#  average strikes per minute, takedown accuracy, submissions) into the fight dataset,
#  computes differences between Red and Blue fighters for each feature, and produces
#  a clean feature matrix (X_men) and target vector (y_men) ready for modeling.

# %%
import re
from sklearn.preprocessing import LabelEncoder

# 1. Define the 8 core divisions as a search pattern
# We use a "|" (OR) to search for any of these keywords
core_pattern = 'Flyweight|Bantamweight|Featherweight|Lightweight|Welterweight|Middleweight|Light Heavyweight|Heavyweight'

# 2. Extract the core name from messy strings
# This converts "UFC Bantamweight Title" -> "Bantamweight"
# flags=re.IGNORECASE handles "lightweight" vs "Lightweight"
df_balanced['weight_class'] = df_balanced['weight_class'].str.extract(f'({core_pattern})', flags=re.IGNORECASE, expand=False)

# 3. Drop rows that didn't match any of the 8 (e.g., Strawweight, Catchweight, or NaNs)
df_balanced = df_balanced.dropna(subset=['weight_class']).copy()

# 4. Standardize capitalization
# .str.title() ensures "Light Heavyweight" is capitalized correctly
df_balanced['weight_class'] = df_balanced['weight_class'].str.title()

# --- Continue with feature matrix creation ---
pre_fight_features = [
    "weight_class", "age_diff", "height_diff", "weight_diff", "reach_diff",
    "wins_total_diff", "losses_total_diff", "r_stance", "b_stance"
]

X_men = df_balanced[pre_fight_features].copy()
y_men = df_balanced["winner"]

# One-Hot Encode and strip the prefix as discussed
X_men = pd.get_dummies(X_men, columns=['weight_class', 'r_stance', 'b_stance'], drop_first=True)
X_men.columns = [col.replace('weight_class_', '') for col in X_men.columns]

# Fill missing values
X_men = X_men.fillna(X_men.mean())

# label encode the target
le = LabelEncoder()
y_men = le.fit_transform(y_men)

# Sanity Check
print(f"Cleaned Divisions: {X_men.columns[-7:].tolist()}") # Shows the last few columns (your weight classes)
X_men.head(20)
# Out:
# Cleaned Divisions: ['r_stance_Sideways', 'r_stance_Southpaw', 'r_stance_Switch', 'b_stance_Orthodox', 'b_stance_Sideways', 'b_stance_Southpaw', 'b_stance_Switch']
#     age_diff  height_diff  weight_diff  reach_diff  wins_total_diff  \
# 0        4.0         7.62       -13.16       12.70                3
# 1       -6.0         2.54         0.00       -2.54                6
# 2        2.0         5.08         0.00        7.62               -1
# 3        8.0         0.00         0.00       -5.08                4
# 4       -2.0         7.62         0.00       17.78                8
# 5        3.0         0.00         0.00       -5.08                4
# 6       -6.0       -10.16         0.00       -5.08              -13
# 7       -7.0        -7.62         0.00      -12.70               -6
# 8       -1.0         0.00         0.00        0.00                5
# 9       -5.0         0.00         0.00        5.08                0
# 10       6.0        -5.08       -11.79        0.00                2
# 11      -7.0        -2.54         6.81       -7.62              -10
# 12       9.0        -5.08         0.00       -7.62               15
# 13      -1.0         0.00         0.00        0.00                5
# 14       2.0         2.54         0.00       12.70               18
# 15       1.0        -7.62         0.00       -2.54               -3
# 16      -2.0         0.00         0.00      -12.70                4
# 17       2.0        -2.54         0.00        7.62                2
# 18      -2.0        -5.08         0.00       -2.54               10
# 19      -6.0         2.54         0.00        7.62               -5
#
#     losses_total_diff  Featherweight  Flyweight  Heavyweight  \
# 0                  -3          False      False         True
# 1                   1          False      False        False
# 2                  -2          False      False        False
# 3                   1           True      False        False
# 4                   3           True      False        False
# 5                   2          False      False        False
# 6                  -6           True      False        False
# 7                  -8          False      False        False
# 8                   3           True      False        False
# 9                   1          False       True        False
# 10                  3          False      False         True
# 11                 -1          False      False         True
# 12                 12          False      False        False
# 13                  0           True      False        False
# 14                  5          False      False        False
# 15                  0          False      False        False
# 16                 -4          False       True        False
# 17                  2           True      False        False
# 18                  5          False      False        False
# 19                 -3          False      False        False
#
#     Light Heavyweight  ...  Middleweight  Welterweight  r_stance_Orthodox  \
# 0               False  ...         False         False               True
# 1               False  ...          True         False               True
# 2               False  ...         False         False              False
# 3               False  ...         False         False               True
# 4               False  ...         False         False               True
# 5               False  ...         False         False               True
# 6               False  ...         False         False               True
# 7               False  ...         False         False               True
# 8               False  ...         False         False               True
# 9               False  ...         False         False               True
# 10              False  ...         False         False               True
# 11              False  ...         False         False              False
# 12               True  ...         False         False              False
# 13              False  ...         False         False               True
# 14              False  ...          True         False              False
# 15              False  ...         False         False              False
# 16              False  ...         False         False               True
# 17              False  ...         False         False               True
# 18              False  ...         False         False               True
# 19              False  ...         False         False               True
#
#     r_stance_Sideways  r_stance_Southpaw  r_stance_Switch  b_stance_Orthodox  \
# 0               False              False            False              False
# 1               False              False            False               True
# 2               False              False             True              False
# 3               False              False            False              False
# 4               False              False            False               True
# 5               False              False            False               True
# 6               False              False            False              False
# 7               False              False            False               True
# 8               False              False            False              False
# 9               False              False            False               True
# 10              False              False            False               True
# 11              False               True            False               True
# 12              False               True            False              False
# 13              False              False            False               True
# 14              False               True            False              False
# 15              False               True            False               True
# 16              False              False            False              False
# 17              False              False            False              False
# 18              False              False            False               True
# 19              False              False            False               True
#
#     b_stance_Sideways  b_stance_Southpaw  b_stance_Switch
# 0               False               True            False
# 1               False              False            False
# 2               False               True            False
# 3               False              False             True
# 4               False              False            False
# 5               False              False            False
# 6               False               True            False
# 7               False              False            False
# 8               False              False             True
# 9               False              False            False
# 10              False              False            False
# 11              False              False            False
# 12              False               True            False
# 13              False              False            False
# 14              False               True            False
# 15              False              False            False
# 16              False               True            False
# 17              False              False             True
# 18              False              False            False
# 19              False              False            False
#
# [20 rows x 21 columns]

# %%
# Create a new 'winner_name' column
# If 'winner' is 'Red', use the name in 'r_fighter'; otherwise, use the name in 'b_fighter'
mdf['winner_name'] = np.where(mdf['winner'] == 'Red', mdf['r_fighter'], mdf['b_fighter'])

# Verify the results
print("Recent fight outcomes with winner names:")
display(mdf[['r_fighter', 'b_fighter', 'winner', 'winner_name']].head())
# Out:
# Recent fight outcomes with winner names:
#            r_fighter        b_fighter winner       winner_name
# 1      Karl Williams      Justin Tafa    Red     Karl Williams
# 2   Edmen Shahbazyan        AJ Dobson    Red  Edmen Shahbazyan
# 3     Payton Talbott  Cameron Saaiman    Red    Payton Talbott
# 4  Billy Quarantillo    Youssef Zalal   Blue     Youssef Zalal
# 5   Fernando Padilla     Luis Pajuelo    Red  Fernando Padilla

# %% [markdown]
# ## MODELING
#
# Time to start modeling. We will use a simple SVM model to set up as a benchmark before continuing to engineer rolling features that can give our models an idea of how fighters are performing before the fight. This avoids target leakage risk seen in some of the variables present in the dataset.

# %%
# SVM Benchmark Model

import random

from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold, cross_val_predict
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

# set seed for reproducibility
SEED = 42

np.random.seed(SEED)
random.seed(SEED)

# create SVM pipeline. avoid data leakage
svm_model = Pipeline([
    ('scaler', StandardScaler()),
    ('svm', SVC(kernel='rbf', random_state=SEED))
])

# use standard 5 fold cross validation
cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,   # randomly shuffle observations before creating folds
    random_state=SEED
)

# cross validated predictions
y_pred = cross_val_predict(
    svm_model,
    X_men,
    y_men,
    cv=cv
)

# print results
accuracy = accuracy_score(y_men, y_pred)
precision = precision_score(y_men, y_pred)
recall = recall_score(y_men, y_pred)
f1 = f1_score(y_men, y_pred)

print("SVM Benchmark (5-Fold CV)\n")
print(f"Accuracy : {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
# Out:
# SVM Benchmark (5-Fold CV)
#
# Accuracy : 0.4618
# Precision: 0.4623
# Recall   : 0.4691
# F1 Score : 0.4657

# %% [markdown]
# After some dissapointing resutls we will move on and perform hyperparameter tunning. We will also be using different kernels and evaluate them.

# %%
# hyperparameter tuning using GridSearch

from sklearn.model_selection import GridSearchCV

param_grid = {
    'svm__C': [0.1, 1, 10, 100],
    'svm__gamma': ['scale', 'auto'],
    'svm__kernel': ['rbf']
}

grid = GridSearchCV(
    estimator=Pipeline([
        ('scaler', StandardScaler()),
        ('svm', SVC())
    ]),
    param_grid=param_grid,
    cv=cv,
    scoring='f1'
)

grid.fit(X_men, y_men)

print("BEST PARAMETERS:")
print(grid.best_params_)
print("\nBEST CV F1 SCORE:", grid.best_score_)
# Out:
# BEST PARAMETERS:
# {'svm__C': 0.1, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
#
# BEST CV F1 SCORE: 0.510129481725902

# %% [markdown]
# GridSearch was really slow. Will improve later on. Consider RandomizedSearch or n_jobs=-1 to use all available

# %%
best_model = grid.best_estimator_

y_pred_best = cross_val_predict(
    best_model,
    X_men,
    y_men,
    cv=cv
)

print("TUNED SVM (5-Fold CV)\n")
print("Accuracy :", accuracy_score(y_men, y_pred_best))
print("Precision:", precision_score(y_men, y_pred_best))
print("Recall   :", recall_score(y_men, y_pred_best))
print("F1 Score :", f1_score(y_men, y_pred_best))
